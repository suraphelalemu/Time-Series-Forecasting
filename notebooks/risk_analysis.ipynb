# %% [markdown]
# ## Risk analysis

# %%
# 📊 Import necessary libraries
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns  
import os  
import sys

# %%
# 🛠️ Add the 'scripts' directory to the Python path for module imports
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))

# %%
# 📚 Importing the DataPreprocessor class from the scripts directory
from data_preprocessing import DataPreprocessor 
from risk_analysis import RiskAnalysis

# %%
# 🛠️ Create an instance of DataPreprocessor
processor = DataPreprocessor()

# %%
bnd_data = processor.load_data('BND')
spy_data = processor.load_data('SPY')
tsla_data = processor.load_data('TSLA')
# Out:
# 📊 Loading data for BND from '../data/BND.csv'.
# 📊 Loading data for SPY from '../data/SPY.csv'.
# 📊 Loading data for TSLA from '../data/TSLA.csv'.

# %%
# Define dictionary for stock data for BND, SPY, TSLA
data_dict = {"BND": bnd_data, "SPY": spy_data, "TSLA": tsla_data}

# Create instace of the RiskAnalysis class
analyzer = RiskAnalysis(data_dict)

# Analyze the risk
analyzer.analyze_risk_and_return()
# Out:
# BND VaR at 95.0% confidence: -0.46%
# BND Sharpe Ratio: -0.23
# SPY VaR at 95.0% confidence: -1.54%
# SPY Sharpe Ratio: -0.67
# TSLA VaR at 95.0% confidence: -5.60%
# TSLA Sharpe Ratio: -0.31
#            VaR  Sharpe Ratio
# BND  -0.004561     -0.227301
# SPY  -0.015393     -0.668712
# TSLA -0.055994     -0.310755
